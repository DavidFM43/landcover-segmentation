# %% [markdown]
# # **Deepglobe Training**

# %% [markdown]
# ## Setup

# %% [markdown]
# Download repository, install dependencies and move the data:

# %%
old_data_dir = "/kaggle/input/deepglobe-land-cover-classification-procesed/data/"
new_data_dir = "/kaggle/working/landcover-segmentation/data/"

# NOTE: cloning "train_script" branch for now
! git clone -b train_script https://github.com/DavidFM43/landcover-segmentation.git
! mv "$old_data_dir"* "$new_data_dir" 2>/dev/null
# %cd /kaggle/working/landcover-segmentation
! pip install -q -r requirements.txt

# %%
# !python train.py
