# %% [markdown]
# <a href="https://www.kaggle.com/code/davidfmora/deepglobe-train/notebook" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **Deepglobe Training**

# %% [markdown]
# ## Setup

# %% [markdown]
# Download repository, install dependencies and move the data:

# %%
old_data_dir = "/kaggle/input/deepglobe-land-cover-classification-procesed/data/"
new_data_dir = "/kaggle/working/landcover-segmentation/data"

! pip install segmentation_models_pytorch -q
! git clone https://github.com/DavidFM43/landcover-segmentation.git
! mv "$old_data_dir"* "$new_data_dir" 2>/dev/null

# %% [markdown]
# Move to the root of the repository:

# %%
cd /kaggle/working/landcover-segmentation

# %% [markdown]
# ## **Run training script**
#
# **Note**: If you want to log the training to Weights and Biases you should first add their API key as a Kaggle secret. To do this, go to the "Add-ons" tab and click on "Secrets", then add a new secret with the label "wandb_key" and the value of your private API key. After that is done simple add the `--log` when running the `train.py` script.

# %%
! python3 train.py --config config.yaml
